# %%
import cv2

# %% [markdown]
# ## read image

# %%
img = cv2.imread('input.jpg')
print(type(img))
print(img.ndim)
# Out:
# <class 'numpy.ndarray'>
# 3

# %% [markdown]
# ## show image

# %%
cv2.imshow('my image',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ## see one BGR data from h,w

# %%
img[100,200]
# Out:
# array([232, 179, 128], dtype=uint8)

# %% [markdown]
# ## show image using matplotlib

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
# img = img[:,:,::-1]
# plt.imshow(img)

img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# ## change image data

# %%
img.shape #hight , width, channels
# Out:
# (600, 800, 3)

# %%
img[100:200,200:300] = (255,0,255)
plt.imshow(img)
