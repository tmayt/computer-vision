# %%
import pandas as pd

# %%
iris = pd.read_csv('iris.csv')

# %%
print(iris)
iris.describe()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]
#        sepal.length  sepal.width  petal.length  petal.width
# ...

# %%
sepal_length = iris['sepal.length']
sepal_length.sum()
sepal_length.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal.length, dtype: float64

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.head(10)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
iris.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris.tail(10)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 140           6.7          3.1           5.6          2.4  Virginica
# 141           6.9          3.1           5.1          2.3  Virginica
# 142           5.8          2.7           5.1          1.9  Virginica
# 143           6.8          3.2           5.9          2.3  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris['variety'].describe()
# Out:
# count        150
# unique         3
# top       Setosa
# freq          50
# Name: variety, dtype: object

# %%
iris.describe(include="all")
# Out:
#         sepal.length  sepal.width  petal.length  petal.width variety
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  Setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
iris.describe(include="number")
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include="object")
# Out:
#        variety
# count      150
# unique       3
# top     Setosa
# freq        50

# %%
sepal_length = iris['sepal.length']
print(sepal_length.max())
print(sepal_length.min())
print(sepal_length.idxmax())
print(sepal_length.idxmin())
# Out:
# 7.9
# 4.3
# 131
# 13

# %%
iris.to_csv('out.csv')

# %%
print(iris['sepal.length'] + iris['sepal.width'])
print(iris['sepal.length'] * iris['sepal.width'])
print(iris['sepal.length'] / iris['sepal.width'])
# Out:
# 0      8.6
# 1      7.9
# 2      7.9
# 3      7.7
# 4      8.6
#       ...
# 145    9.7
# 146    8.8
# 147    9.5
# 148    9.6
# 149    8.9
# Length: 150, dtype: float64
# 0      17.85
# 1      14.70
# 2      15.04
# 3      14.26
# 4      18.00
#        ...
# 145    20.10
# 146    15.75
# 147    19.50
# 148    21.08
# 149    17.70
# Length: 150, dtype: float64
# 0      1.457143
# 1      1.633333
# 2      1.468750
# 3      1.483871
# 4      1.388889
#          ...
# 145    2.233333
# 146    2.520000
# 147    2.166667
# 148    1.823529
# 149    1.966667
# Length: 150, dtype: float64

# %%
print(iris['variety'] == 'Virginica')
print(iris['sepal.length'] > iris['sepal.width'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: variety, Length: 150, dtype: bool
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Length: 150, dtype: bool

# %%
new_series = iris['variety'] == 'Virginica'
iris = iris.assign(is_Virginica=new_series)
 
iris = iris.assign(ratio_len =iris['sepal.length'] / iris['petal.length'], x=iris['sepal.length'] + iris['ratio_len'])
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      is_Virginica  ratio_len         x
# 0           False   3.642857  8.742857
# 1           False   3.500000  8.400000
# ...

# %%
iris.query('ratio_len > 2').head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  is_Virginica  \
# 0           5.1          3.5           1.4          0.2  Setosa         False
# 1           4.9          3.0           1.4          0.2  Setosa         False
# 2           4.7          3.2           1.3          0.2  Setosa         False
# 3           4.6          3.1           1.5          0.2  Setosa         False
# 4           5.0          3.6           1.4          0.2  Setosa         False
#
#    ratio_len
# 0   3.642857
# 1   3.500000
# 2   3.615385
# 3   3.066667
# 4   3.571429

# %%
iris.plot(kind="scatter",x='sepal.length',y='petal.length')
# Out:
# <Axes: xlabel='sepal.length', ylabel='petal.length'>

# %%
iris['ratio_len']
iris.loc[1]
iris.iloc[1]
iris[100:150:2]
df = iris[iris['is_Virginica'] == False]
df[iris['sepal.length'] > 5]
# Out:
# /tmp/ipykernel_12377/596677268.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[iris['sepal.length'] > 5]
#     sepal.length  sepal.width  petal.length  petal.width     variety  \
# 0            5.1          3.5           1.4          0.2      Setosa
# 5            5.4          3.9           1.7          0.4      Setosa
# 10           5.4          3.7           1.5          0.2      Setosa
# 14           5.8          4.0           1.2          0.2      Setosa
# 15           5.7          4.4           1.5          0.4      Setosa
# ..           ...          ...           ...          ...         ...
# 95           5.7          3.0           4.2          1.2  Versicolor
# 96           5.7          2.9           4.2          1.3  Versicolor
# 97           6.2          2.9           4.3          1.3  Versicolor
# 98           5.1          2.5           3.0          1.1  Versicolor
# ...
